# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilkharade/nikhilF/blob/master/911.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fbf96ea3-e865-49d9-9b07-40d1eb86f125" name="files[]" multiple disabled />
#      <output id="result-fbf96ea3-e865-49d9-9b07-40d1eb86f125">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 911.csv to 911.csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("911.csv" , skipinitialspace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423909 entries, 0 to 423908
# Data columns (total 9 columns):
# lat          423909 non-null float64
# lng          423909 non-null float64
# desc         423909 non-null object
# zip          371780 non-null float64
# title        423909 non-null object
# timeStamp    423909 non-null object
# twp          423750 non-null object
# addr         423909 non-null object
# e            423909 non-null int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 29.1+ MB

# %%
df.head()
# Out:
#          lat        lng  ...                        addr  e
# 0  40.297876 -75.581294  ...      REINDEER CT & DEAD END  1
# 1  40.258061 -75.264680  ...  BRIAR PATH & WHITEMARSH LN  1
# 2  40.121182 -75.351975  ...                    HAWS AVE  1
# 3  40.116153 -75.343513  ...          AIRY ST & SWEDE ST  1
# 4  40.251492 -75.603350  ...    CHERRYWOOD CT & DEAD END  1
#
# [5 rows x 9 columns]

# %%
df["zip"].value_counts().head(5)
# Out:
# 19401.0    28656
# 19464.0    27948
# 19403.0    21631
# 19446.0    20496
# 19406.0    14097
# Name: zip, dtype: int64

# %%
df['twp'].value_counts().head(5)
# Out:
# LOWER MERION    36441
# ABINGTON        25835
# NORRISTOWN      23883
# UPPER MERION    22694
# CHELTENHAM      19629
# Name: twp, dtype: int64

# %%
df['title'].nunique()
# Out:
# 141

# %%
x=df['title'].iloc[0]
x
# Out:
# 'EMS: BACK PAINS/INJURY'

# %%
x.split(':')[0]
# Out:
# 'EMS'

# %%
df['Reason'] = df['title'].str.split(":").str[0]

# %%
df['Reason'].value_counts()
# Out:
# EMS        208676
# Traffic    151458
# Fire        63775
# Name: Reason, dtype: int64

# %%
sns.countplot(x='Reason' , data = df )

# %%
type(df['timeStamp'].iloc[0])
# Out:
# str

# %%
df["timeStamp"] = pd.to_datetime(df["timeStamp"])
type(df['timeStamp'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
time = df['timeStamp'].iloc[0]
time.hour
# Out:
# 17

# %%
df["Hour"] = df['timeStamp'].apply(lambda time: time.hour )
df["Month"] = df['timeStamp'].apply(lambda time: time.month )
df["Day of Week"] = df['timeStamp'].apply(lambda time: time.dayofweek )

# %%
df.head()
# Out:
#          lat        lng  ... Month  Day of Week
# 0  40.297876 -75.581294  ...    12            3
# 1  40.258061 -75.264680  ...    12            3
# 2  40.121182 -75.351975  ...    12            3
# 3  40.116153 -75.343513  ...    12            3
# 4  40.251492 -75.603350  ...    12            3
#
# [5 rows x 13 columns]

# %%
dmap = {0:"Mon",1:"Tue",2:"Wed",3:"Thu",4:"Fri",5:"Sat",6:"Sun"}

# %%
dmap[1]
# Out:
# 'Tue'

# %%
df['Day of Week'] = df['Day of Week'].replace(dmap)

# %%
df.head()
# Out:
#          lat        lng  ... Month  Day of Week
# 0  40.297876 -75.581294  ...    12          Thu
# 1  40.258061 -75.264680  ...    12          Thu
# 2  40.121182 -75.351975  ...    12          Thu
# 3  40.116153 -75.343513  ...    12          Thu
# 4  40.251492 -75.603350  ...    12          Thu
#
# [5 rows x 13 columns]

# %%
sns.countplot(x='Day of Week' , data = df , hue = 'Reason' , palette= "viridis")
plt.legend(bbox_to_anchor=(1.05,1) , loc=2 , borderaxespad=0)

# %%
sns.countplot(x='Month' , data = df , hue = 'Reason' , palette= "viridis")
plt.legend(bbox_to_anchor=(1.05,1) , loc=2 , borderaxespad=0)

# %%
t =df['timeStamp'].iloc[0]

# %%
df["Date"] = df['timeStamp'].apply(lambda t:t.date())

# %%
df.head()
# Out:
#          lat        lng  ... Day of Week        Date
# 0  40.297876 -75.581294  ...         Thu  2015-12-10
# 1  40.258061 -75.264680  ...         Thu  2015-12-10
# 2  40.121182 -75.351975  ...         Thu  2015-12-10
# 3  40.116153 -75.343513  ...         Thu  2015-12-10
# 4  40.251492 -75.603350  ...         Thu  2015-12-10
#
# [5 rows x 14 columns]

# %%
plt.figure(figsize=(20,6))
df.groupby('Date').count()['lat'].plot()
plt.tight_layout()

# %%
plt.figure(figsize=(20,6))
df[df['Reason']=='Traffic'].groupby('Date').count()['lat'].plot()
plt.tight_layout()

# %%
plt.figure(figsize=(20,6))
df[df['Reason']=='EMS'].groupby('Date').count()['lat'].plot()
plt.tight_layout()

# %%
plt.figure(figsize=(20,6))
df[df['Reason']=='Fire'].groupby('Date').count()['lat'].plot()
plt.tight_layout()

# %%
dayHour = df.groupby(by=['Day of Week', 'Hour']).count()['Reason'].unstack()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(dayHour , cmap ='viridis' )

# %%
plt.figure(figsize=(12,6))
sns.clustermap(dayHour , cmap = 'viridis')
